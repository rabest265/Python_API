# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from datetime import datetime as dt
from pprint import pprint
import openweathermapy.core as owm

# Import API key
from api_keys import (google_key, weather_api_key)

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
city_lat_lng = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name + ","+ citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 603

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build the endpoint URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Set up arrays
weather_city = []
temp = []
cloud = []
country = []
date = []
humid = []
lat = []
lng = []
max_temp = []
wind = []
i = 0

print ("Beginning Data Retrieval")
print ("-----------------------------")
       
# Loop through the list of cities and perform a request for data on each
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        temp.append(response['main']['temp'])
        weather_city.append(city)
        cloud.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humid.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response["main"]["temp_max"])
        wind.append(response["wind"]["speed"]) 
        i += 1
        print("Processing Record " + str(i) + " | " + city)
    except KeyError:
        print ("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 1 | nanortalik,gl
# City not found. Skipping...
# Processing Record 2 | faanui,pf
# Processing Record 3 | bambous virieux,mu
# Processing Record 4 | rikitea,pf
# Processing Record 5 | ushuaia,ar
# Processing Record 6 | jacareacanga,br
# Processing Record 7 | zhanaozen,kz
# Processing Record 8 | oyon,pe
# Processing Record 9 | mahebourg,mu
# Processing Record 10 | yanam,in
# Processing Record 11 | udayagiri,in
# Processing Record 12 | punta arenas,cl
# Processing Record 13 | san ramon,bo
# Processing Record 14 | butaritari,ki
# Processing Record 15 | kavieng,pg
# Processing Record 16 | hithadhoo,mv
# Processing Record 17 | lebu,cl
# Processing Record 18 | mareeba,au
# Processing Record 19 | estevan,ca
# Processing Record 20 | albany,au
# Processing Record 21 | verkhoyansk,ru
# Processing Record 22 | hobart,au
# Processing Record 23 | mataro,es
# Processing Record 24 | zhenjiang,cn
# Processing Record 25 | vaini,to
# Processing Record 26 | longyearbyen,sj
# Processing Record 27 | kawambwa,zm
# Processing Record 28 | itaituba,br
# Processing Record 29 | barrow,us
# Processing Record 30 | bambanglipuro,id
# Processing Record 31 | port alfred,za
# Processing Record 32 | busselton,au
# Processing Record 33 | kapaa,us
# Processing Record 34 | darlawn,in
# Processing Record 35 | ximei,cn
# Processing Record 36 | yemtsa,ru
# Processing Record 37 | buraydah,sa
# Processing Record 38 | hilo,us
# Processing Record 39 | qaanaaq,gl
# Processing Record 40 | lazaro cardenas,mx
# Processing Record 41 | atuona,pf
# Processing Record 42 | ayna,pe
# Processing Record 43 | am timan,td
# Processing Record 44 | maceio,br
# Processing Record 45 | donghai,cn
# Processing Record 46 | buchanan,lr
# Processing Record 47 | comodoro rivadavia,ar
# Processing Record 48 | benguela,ao
# Processing Record 49 | mwense,zm
# Processing Record 50 | ust-kuyga,ru
# Processing Record 51 | bluff,nz
# Processing Record 52 | igarka,ru
# Processing Record 53 | saskylakh,ru
# City not found. Skipping...
# Processing Record 54 | prince rupert,ca
# Processing Record 55 | yellowknife,ca
# Processing Record 56 | sochi,ru
# Processing Record 57 | khatanga,ru
# Processing Record 58 | castro,cl
# Processing Record 59 | puerto ayora,ec
# Processing Record 60 | masterton,nz
# City not found. Skipping...
# Processing Record 61 | aklavik,ca
# Processing Record 62 | grants,us
# Processing Record 63 | mizdah,ly
# Processing Record 64 | sur,om
# Processing Record 65 | bredasdorp,za
# Processing Record 66 | miandoab,ir
# Processing Record 67 | cape town,za
# Processing Record 68 | norman wells,ca
# Processing Record 69 | rawa mazowiecka,pl
# Processing Record 70 | mumford,gh
# Processing Record 71 | port elizabeth,za
# Processing Record 72 | nelson bay,au
# Processing Record 73 | spas-demensk,ru
# Processing Record 74 | geraldton,au
# Processing Record 75 | flinders,au
# Processing Record 76 | broome,au
# Processing Record 77 | tamandare,br
# Processing Record 78 | jamestown,sh
# Processing Record 79 | nikolskoye,ru
# Processing Record 80 | upernavik,gl
# Processing Record 81 | isangel,vu
# Processing Record 82 | arraial do cabo,br
# Processing Record 83 | mezen,ru
# Processing Record 84 | anadyr,ru
# Processing Record 85 | coihaique,cl
# Processing Record 86 | amuntai,id
# Processing Record 87 | sao filipe,cv
# Processing Record 88 | cidreira,br
# Processing Record 89 | esperance,au
# Processing Record 90 | miyako,jp
# Processing Record 91 | chokurdakh,ru
# City not found. Skipping...
# Processing Record 92 | linhares,br
# Processing Record 93 | mar del plata,ar
# Processing Record 94 | kathu,th
# City not found. Skipping...
# Processing Record 95 | halifax,ca
# Processing Record 96 | vestmannaeyjar,is
# Processing Record 97 | jiaozhou,cn
# City not found. Skipping...
# Processing Record 98 | winchester,ca
# Processing Record 99 | new norfolk,au
# Processing Record 100 | karhal,in
# Processing Record 101 | chulman,ru
# Processing Record 102 | valparaiso,cl
# City not found. Skipping...
# Processing Record 103 | charters towers,au
# Processing Record 104 | pevek,ru
# Processing Record 105 | east london,za
# Processing Record 106 | kodinsk,ru
# Processing Record 107 | richards bay,za
# Processing Record 108 | shalya,ru
# Processing Record 109 | niigata,jp
# Processing Record 110 | nome,us
# Processing Record 111 | cherskiy,ru
# Processing Record 112 | hermanus,za
# Processing Record 113 | half moon bay,us
# Processing Record 114 | dhidhdhoo,mv
# Processing Record 115 | hofn,is
# Processing Record 116 | avarua,ck
# City not found. Skipping...
# Processing Record 117 | luderitz,na
# Processing Record 118 | watertown,us
# Processing Record 119 | afyonkarahisar,tr
# Processing Record 120 | karratha,au
# Processing Record 121 | pangody,ru
# Processing Record 122 | saint-philippe,re
# City not found. Skipping...
# Processing Record 123 | sasayama,jp
# Processing Record 124 | ribeira grande,pt
# Processing Record 125 | muhos,fi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 126 | tasiilaq,gl
# Processing Record 127 | tiksi,ru
# Processing Record 128 | nizhniy kuranakh,ru
# City not found. Skipping...
# Processing Record 129 | kodiak,us
# Processing Record 130 | huarmey,pe
# Processing Record 131 | guerrero negro,mx
# Processing Record 132 | husavik,is
# Processing Record 133 | guymon,us
# Processing Record 134 | shelburne,ca
# City not found. Skipping...
# Processing Record 135 | meulaboh,id
# Processing Record 136 | okakarara,na
# Processing Record 137 | bulawayo,zw
# Processing Record 138 | iqaluit,ca
# City not found. Skipping...
# Processing Record 139 | ilulissat,gl
# Processing Record 140 | cabo san lucas,mx
# Processing Record 141 | port blair,in
# Processing Record 142 | torbay,ca
# Processing Record 143 | alekseyevsk,ru
# Processing Record 144 | narsaq,gl
# Processing Record 145 | preston,us
# Processing Record 146 | san antonio,us
# Processing Record 147 | victoria,sc
# Processing Record 148 | klaksvik,fo
# Processing Record 149 | port shepstone,za
# Processing Record 150 | gotsu,jp
# Processing Record 151 | dikson,ru
# Processing Record 152 | atambua,id
# Processing Record 153 | talara,pe
# Processing Record 154 | ponta do sol,cv
# Processing Record 155 | north bend,us
# Processing Record 156 | botwood,ca
# City not found. Skipping...
# Processing Record 157 | inhambane,mz
# Processing Record 158 | rocha,uy
# Processing Record 159 | dingle,ie
# Processing Record 160 | cairns,au
# Processing Record 161 | vega de alatorre,mx
# Processing Record 162 | itarantim,br
# Processing Record 163 | aripuana,br
# Processing Record 164 | coquimbo,cl
# Processing Record 165 | stryn,no
# Processing Record 166 | mehamn,no
# Processing Record 167 | makakilo city,us
# Processing Record 168 | omidiyeh,ir
# Processing Record 169 | saldanha,za
# Processing Record 170 | ambon,id
# City not found. Skipping...
# Processing Record 171 | pangnirtung,ca
# Processing Record 172 | talnakh,ru
# City not found. Skipping...
# Processing Record 173 | abu dhabi,ae
# Processing Record 174 | tautira,pf
# Processing Record 175 | carnarvon,au
# Processing Record 176 | mayo,ca
# Processing Record 177 | fortuna,us
# Processing Record 178 | kahului,us
# Processing Record 179 | seoul,kr
# Processing Record 180 | katsuura,jp
# Processing Record 181 | kaliwungu,id
# Processing Record 182 | portland,au
# Processing Record 183 | sitka,us
# City not found. Skipping...
# Processing Record 184 | cabra,ph
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 185 | poykovskiy,ru
# Processing Record 186 | mombaca,br
# City not found. Skipping...
# Processing Record 187 | georgetown,sh
# Processing Record 188 | san rafael,bo
# Processing Record 189 | kaitangata,nz
# Processing Record 190 | padang,id
# City not found. Skipping...
# Processing Record 191 | kangaatsiaq,gl
# City not found. Skipping...
# Processing Record 192 | lagoa,pt
# Processing Record 193 | santa rosa,ar
# Processing Record 194 | cayenne,gf
# Processing Record 195 | byron bay,au
# City not found. Skipping...
# Processing Record 196 | bethel,us
# Processing Record 197 | san jose,gt
# Processing Record 198 | baykit,ru
# Processing Record 199 | thompson,ca
# Processing Record 200 | araouane,ml
# Processing Record 201 | blackfoot,us
# Processing Record 202 | labuhan,id
# Processing Record 203 | funtua,ng
# Processing Record 204 | tshela,cd
# Processing Record 205 | champerico,gt
# Processing Record 206 | sao jose da coroa grande,br
# Processing Record 207 | copiapo,cl
# Processing Record 208 | chifeng,cn
# Processing Record 209 | atar,mr
# Processing Record 210 | peniche,pt
# City not found. Skipping...
# Processing Record 211 | raudeberg,no
# Processing Record 212 | hare bay,ca
# Processing Record 213 | pasighat,in
# Processing Record 214 | haines junction,ca
# Processing Record 215 | kondinskoye,ru
# Processing Record 216 | bubaque,gw
# City not found. Skipping...
# Processing Record 217 | sainte-suzanne,re
# Processing Record 218 | mandalgovi,mn
# Processing Record 219 | ha giang,vn
# Processing Record 220 | nchelenge,zm
# Processing Record 221 | acapulco,mx
# Processing Record 222 | ahipara,nz
# Processing Record 223 | necochea,ar
# Processing Record 224 | yar-sale,ru
# Processing Record 225 | hazleton,us
# City not found. Skipping...
# Processing Record 226 | bonavista,ca
# Processing Record 227 | horasan,tr
# City not found. Skipping...
# Processing Record 228 | saint george,bm
# Processing Record 229 | vao,nc
# City not found. Skipping...
# Processing Record 230 | fujin,cn
# Processing Record 231 | teknaf,bd
# Processing Record 232 | luganville,vu
# Processing Record 233 | songjianghe,cn
# City not found. Skipping...
# Processing Record 234 | kimparana,ml
# Processing Record 235 | krasnyy oktyabr,ru
# Processing Record 236 | general roca,ar
# Processing Record 237 | hami,cn
# Processing Record 238 | leningradskiy,ru
# Processing Record 239 | gigmoto,ph
# Processing Record 240 | sabang,id
# Processing Record 241 | nanzhou,cn
# Processing Record 242 | winnemucca,us
# Processing Record 243 | port macquarie,au
# Processing Record 244 | konstantinovskiy,ru
# Processing Record 245 | pozo colorado,py
# City not found. Skipping...
# Processing Record 246 | kysyl-syr,ru
# City not found. Skipping...
# Processing Record 247 | namatanai,pg
# Processing Record 248 | chimore,bo
# City not found. Skipping...
# Processing Record 249 | tuktoyaktuk,ca
# Processing Record 250 | carlyle,ca
# Processing Record 251 | yokote,jp
# Processing Record 252 | narasannapeta,in
# Processing Record 253 | kaspiyskiy,ru
# Processing Record 254 | lorengau,pg
# Processing Record 255 | saint-joseph,re
# Processing Record 256 | yen bai,vn
# City not found. Skipping...
# Processing Record 257 | arkhangelsk,ru
# City not found. Skipping...
# Processing Record 258 | marystown,ca
# Processing Record 259 | warmbad,na
# Processing Record 260 | bandar,id
# Processing Record 261 | san carlos de bariloche,ar
# Processing Record 262 | tuatapere,nz
# Processing Record 263 | barquisimeto,ve
# Processing Record 264 | najran,sa
# Processing Record 265 | ca mau,vn
# Processing Record 266 | bundaberg,au
# Processing Record 267 | puro,ph
# Processing Record 268 | marsh harbour,bs
# Processing Record 269 | vanimo,pg
# City not found. Skipping...
# Processing Record 270 | koriyama,jp
# Processing Record 271 | viransehir,tr
# Processing Record 272 | aragarcas,br
# Processing Record 273 | camacha,pt
# Processing Record 274 | jiuquan,cn
# Processing Record 275 | orlik,ru
# City not found. Skipping...
# Processing Record 276 | lincoln,nz
# Processing Record 277 | catemaco,mx
# Processing Record 278 | college,us
# Processing Record 279 | paamiut,gl
# Processing Record 280 | sibolga,id
# Processing Record 281 | vila franca do campo,pt
# Processing Record 282 | morant bay,jm
# Processing Record 283 | batemans bay,au
# Processing Record 284 | dunedin,nz
# Processing Record 285 | kununurra,au
# Processing Record 286 | shingu,jp
# City not found. Skipping...
# Processing Record 287 | zakopane,pl
# Processing Record 288 | florianopolis,br
# Processing Record 289 | estelle,us
# City not found. Skipping...
# Processing Record 290 | dakar,sn
# Processing Record 291 | san cristobal,ec
# Processing Record 292 | ust-nera,ru
# Processing Record 293 | male,mv
# Processing Record 294 | zhangye,cn
# Processing Record 295 | sulangan,ph
# Processing Record 296 | fukue,jp
# Processing Record 297 | awbari,ly
# Processing Record 298 | menongue,ao
# Processing Record 299 | wanxian,cn
# Processing Record 300 | solnechnyy,ru
# Processing Record 301 | mahibadhoo,mv
# Processing Record 302 | hamilton,bm
# Processing Record 303 | kruisfontein,za
# City not found. Skipping...
# Processing Record 304 | kuldiga,lv
# Processing Record 305 | cheyenne,us
# City not found. Skipping...
# Processing Record 306 | ambilobe,mg
# City not found. Skipping...
# Processing Record 307 | kalaleh,ir
# Processing Record 308 | kutum,sd
# Processing Record 309 | tommot,ru
# Processing Record 310 | hasilpur,pk
# Processing Record 311 | los llanos de aridane,es
# Processing Record 312 | maltahohe,na
# Processing Record 313 | oussouye,sn
# Processing Record 314 | eureka,us
# Processing Record 315 | castanas,ph
# Processing Record 316 | rawson,ar
# Processing Record 317 | damietta,eg
# Processing Record 318 | meridian,us
# Processing Record 319 | calella,es
# City not found. Skipping...
# Processing Record 320 | shimoda,jp
# Processing Record 321 | kabansk,ru
# Processing Record 322 | awjilah,ly
# Processing Record 323 | ampanihy,mg
# Processing Record 324 | hualmay,pe
# Processing Record 325 | ormara,pk
# Processing Record 326 | smidovich,ru
# Processing Record 327 | gornopravdinsk,ru
# Processing Record 328 | kiama,au
# Processing Record 329 | hasaki,jp
# Processing Record 330 | lake jackson,us
# Processing Record 331 | antofagasta,cl
# City not found. Skipping...
# Processing Record 332 | provideniya,ru
# City not found. Skipping...
# Processing Record 333 | amantea,it
# City not found. Skipping...
# Processing Record 334 | souillac,mu
# Processing Record 335 | grindavik,is
# City not found. Skipping...
# Processing Record 336 | saint-pierre,pm
# Processing Record 337 | catuday,ph
# Processing Record 338 | yizheng,cn
# Processing Record 339 | moyale,et
# Processing Record 340 | alta floresta,br
# Processing Record 341 | indaparapeo,mx
# Processing Record 342 | adrar,dz
# City not found. Skipping...
# Processing Record 343 | vardo,no
# Processing Record 344 | roald,no
# City not found. Skipping...
# Processing Record 345 | catia la mar,ve
# Processing Record 346 | djibo,bf
# Processing Record 347 | srednekolymsk,ru
# Processing Record 348 | voyvozh,ru
# City not found. Skipping...
# Processing Record 349 | isla vista,us
# Processing Record 350 | shakawe,bw
# Processing Record 351 | vila velha,br
# Processing Record 352 | ulaangom,mn
# Processing Record 353 | lagos,pt
# Processing Record 354 | samarai,pg
# Processing Record 355 | gizo,sb
# Processing Record 356 | canon city,us
# Processing Record 357 | seddon,nz
# Processing Record 358 | chuy,uy
# Processing Record 359 | veraval,in
# City not found. Skipping...
# Processing Record 360 | arlit,ne
# Processing Record 361 | tera,ne
# City not found. Skipping...
# Processing Record 362 | lavrentiya,ru
# Processing Record 363 | taltal,cl
# Processing Record 364 | venado tuerto,ar
# Processing Record 365 | bonoua,ci
# Processing Record 366 | riviere-au-renard,ca
# Processing Record 367 | mattawa,ca
# City not found. Skipping...
# Processing Record 368 | caravelas,br
# Processing Record 369 | khorramabad,ir
# Processing Record 370 | shitanjing,cn
# Processing Record 371 | kurumkan,ru
# Processing Record 372 | kavaratti,in
# Processing Record 373 | virginia beach,us
# Processing Record 374 | namibe,ao
# Processing Record 375 | ambunti,pg
# Processing Record 376 | plettenberg bay,za
# Processing Record 377 | mount isa,au
# Processing Record 378 | cascais,pt
# Processing Record 379 | touros,br
# Processing Record 380 | neiafu,to
# Processing Record 381 | aswan,eg
# Processing Record 382 | altay,cn
# Processing Record 383 | quatre cocos,mu
# Processing Record 384 | altamira,br
# Processing Record 385 | waingapu,id
# Processing Record 386 | grand gaube,mu
# Processing Record 387 | sangar,ru
# Processing Record 388 | sao joao del rei,br
# Processing Record 389 | clyde river,ca
# Processing Record 390 | rusape,zw
# Processing Record 391 | nivala,fi
# Processing Record 392 | lomovka,ru
# Processing Record 393 | kosh-agach,ru
# Processing Record 394 | salalah,om
# Processing Record 395 | kieta,pg
# Processing Record 396 | aniva,ru
# City not found. Skipping...
# Processing Record 397 | santa cruz de la palma,es
# Processing Record 398 | teluknaga,id
# Processing Record 399 | kjollefjord,no
# Processing Record 400 | maragogi,br
# Processing Record 401 | ngunguru,nz
# Processing Record 402 | hinton,ca
# Processing Record 403 | berlevag,no
# Processing Record 404 | tessalit,ml
# City not found. Skipping...
# Processing Record 405 | parabel,ru
# Processing Record 406 | mugur-aksy,ru
# Processing Record 407 | coahuayana,mx
# Processing Record 408 | bandar-e lengeh,ir
# Processing Record 409 | tarquinia,it
# Processing Record 410 | roma,au
# Processing Record 411 | tarata,pe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 412 | baoro,cf
# Processing Record 413 | severo-kurilsk,ru
# Processing Record 414 | campamento,co
# Processing Record 415 | brae,gb
# Processing Record 416 | shumskiy,ru
# Processing Record 417 | san andres,co
# Processing Record 418 | santa isabel do rio negro,br
# Processing Record 419 | alofi,nu
# Processing Record 420 | maple creek,ca
# Processing Record 421 | gazanjyk,tm
# City not found. Skipping...
# Processing Record 422 | youhao,cn
# Processing Record 423 | sungaipenuh,id
# Processing Record 424 | jardim,br
# City not found. Skipping...
# Processing Record 425 | koslan,ru
# Processing Record 426 | port-gentil,ga
# City not found. Skipping...
# Processing Record 427 | irituia,br
# Processing Record 428 | bull savanna,jm
# Processing Record 429 | gamboma,cg
# Processing Record 430 | partenit,ua
# Processing Record 431 | sao joao da barra,br
# Processing Record 432 | duminichi,ru
# Processing Record 433 | sola,vu
# Processing Record 434 | san patricio,mx
# Processing Record 435 | qasigiannguit,gl
# Processing Record 436 | blackwater,au
# Processing Record 437 | yulara,au
# City not found. Skipping...
# Processing Record 438 | shache,cn
# Processing Record 439 | lima,pe
# Processing Record 440 | cassilandia,br
# Processing Record 441 | puqi,cn
# City not found. Skipping...
# Processing Record 442 | klyuchi,ru
# Processing Record 443 | ponta do sol,pt
# Processing Record 444 | antalaha,mg
# Processing Record 445 | te anau,nz
# Processing Record 446 | oriximina,br
# Processing Record 447 | pacific grove,us
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 448 | barra patuca,hn
# Processing Record 449 | zhengjiatun,cn
# Processing Record 450 | basco,ph
# Processing Record 451 | bathsheba,bb
# Processing Record 452 | puerto escondido,mx
# Processing Record 453 | lompoc,us
# Processing Record 454 | izumo,jp
# City not found. Skipping...
# Processing Record 455 | brigantine,us
# Processing Record 456 | mehnagar,in
# Processing Record 457 | marawi,sd
# Processing Record 458 | yaqui,mx
# City not found. Skipping...
# Processing Record 459 | port hedland,au
# City not found. Skipping...
# Processing Record 460 | bandarbeyla,so
# Processing Record 461 | pyshma,ru
# Processing Record 462 | bom jesus,br
# Processing Record 463 | micheweni,tz
# Processing Record 464 | san jeronimo,mx
# Processing Record 465 | alice springs,au
# City not found. Skipping...
# Processing Record 466 | tigil,ru
# Processing Record 467 | naze,jp
# Processing Record 468 | fairbanks,us
# Processing Record 469 | susurluk,tr
# Processing Record 470 | bacolod,ph
# Processing Record 471 | lucea,jm
# Processing Record 472 | biloela,au
# Processing Record 473 | tilichiki,ru
# Processing Record 474 | honolulu,us
# Processing Record 475 | wilkie,ca
# Processing Record 476 | chapais,ca
# Processing Record 477 | kisangani,cd
# Processing Record 478 | bilma,ne
# Processing Record 479 | hobyo,so
# Processing Record 480 | santiago del estero,ar
# Processing Record 481 | petropavlovsk-kamchatskiy,ru
# Processing Record 482 | alenquer,br
# Processing Record 483 | dhanaula,in
# Processing Record 484 | aitape,pg
# Processing Record 485 | olinda,br
# Processing Record 486 | notodden,no
# Processing Record 487 | slobozia,md
# Processing Record 488 | novo aripuana,br
# Processing Record 489 | nago,jp
# Processing Record 490 | port lincoln,au
# Processing Record 491 | payson,us
# Processing Record 492 | merauke,id
# Processing Record 493 | itarema,br
# Processing Record 494 | council bluffs,us
# Processing Record 495 | freeport,us
# Processing Record 496 | galesong,id
# Processing Record 497 | nusaybin,tr
# Processing Record 498 | nalchiti,bd
# Processing Record 499 | kerema,pg
# Processing Record 500 | porto santo,pt
# City not found. Skipping...
# Processing Record 501 | kiunga,pg
# Processing Record 502 | kindu,cd
# Processing Record 503 | canakkale,tr
# City not found. Skipping...
# Processing Record 504 | kurilsk,ru
# Processing Record 505 | kaniama,cd
# Processing Record 506 | ranong,th
# Processing Record 507 | sisimiut,gl
# Processing Record 508 | nemuro,jp
# Processing Record 509 | henties bay,na
# City not found. Skipping...
# Processing Record 510 | otanche,co
# Processing Record 511 | dudinka,ru
# Processing Record 512 | bamnet narong,th
# Processing Record 513 | bilibino,ru
# Processing Record 514 | somers point,us
# Processing Record 515 | kudahuvadhoo,mv
# City not found. Skipping...
# Processing Record 516 | carutapera,br
# Processing Record 517 | marsa matruh,eg
# Processing Record 518 | maraa,br
# Processing Record 519 | stornoway,gb
# City not found. Skipping...
# Processing Record 520 | farafangana,mg
# Processing Record 521 | columbus,us
# Processing Record 522 | chumikan,ru
# Processing Record 523 | hovd,mn
# Processing Record 524 | port hardy,ca
# Processing Record 525 | chicama,pe
# Processing Record 526 | launceston,au
# Processing Record 527 | kayerkan,ru
# Processing Record 528 | geri,cy
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# response = requests.get(query_url + "Miami").json()
# pprint(response)

# %%
summary_df = pd.DataFrame({"City": weather_city,
                           "Temp": temp,
                           "Cloudiness":cloud,
                           "Country": country,
                           "Date": date,
                           "Humidity": humid,
                           "Lat": lat,
                           "Lng": lng,
                           "Max Temp":max_temp,
                           "Wind Speed": wind
                          })
summary_df.to_csv("output_data_file", encoding="utf-8", index=False)
summary_df.head()
# Out:
#                  City   Temp  Cloudiness Country        Date  Humidity    Lat  \
# 0       nanortalik,gl  -3.00          76      GL  1553048231       100  60.14
# 1           faanui,pf  28.61          68      PF  1553048231       100 -16.48
# 2  bambous virieux,mu  26.14          40      MU  1553048043        78 -20.34
# 3          rikitea,pf  25.36           0      PF  1553048231       100 -23.12
# 4          ushuaia,ar  10.00          40      AR  1553043600        66 -54.81
#
#       Lng  Max Temp  Wind Speed
# 0  -45.24     -3.00       11.07
# 1 -151.75     28.61        2.52
# 2   57.76     27.00        5.10
# 3 -134.97     25.36        9.67
# 4  -68.31     10.00        3.10

# %%
date = summary_df["Date"][0]
year = dt.utcfromtimestamp(date).year
month = dt.utcfromtimestamp(date).month
day = dt.utcfromtimestamp(date).day

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# SCATTER PLOTS - Showing relationships between two sets of data

plt.scatter(summary_df["Lat"], summary_df["Max Temp"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Max Temp (" + str(month) + "/" + str(day) + "/"+ str(year) + ")")
plt.xlim(-100,100)

plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")


# Save the figure
plt.savefig("Max_Temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# SCATTER PLOTS - Showing relationships between two sets of data

plt.scatter(summary_df["Lat"], summary_df["Humidity"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Humidity (" + str(month) + "/" + str(day) + "/"+ str(year) + ")")
plt.ylim(0,100)

plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")


# Save the figure
plt.savefig("Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# SCATTER PLOTS - Showing relationships between two sets of data

plt.scatter(summary_df["Lat"], summary_df["Cloudiness"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Cloudiness (" + str(month) + "/" + str(day) + "/"+ str(year) + ")")
plt.xlim(-100,100)

plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# SCATTER PLOTS - Showing relationships between two sets of data

plt.scatter(summary_df["Lat"], summary_df["Wind Speed"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Wind Speed (" + str(month) + "/" + str(day) + "/"+ str(year) + ")")
plt.xlim(-100,100)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")


# Save the figure
plt.savefig("Wind_Speed.png")
plt.show()
